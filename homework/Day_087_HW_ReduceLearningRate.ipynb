# %% [markdown]
# ## Work
# 1. 請改變 reduce_lr 的 patience 和 factor 並比較不同設定下，對訓練/驗證集的影響
# 2. 請將 optimizer 換成 Adam、RMSprop 搭配 reduce_lr 並比較訓練結果

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

"""
建立神經網路，並加入 BN layer
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
LEARNING_RATE = 1e-3
EPOCHS = 25 # IF you feel too run to finish, try to make it smaller
BATCH_SIZE = 1024 
MOMENTUM = 0.95

# %%
# 載入 Callbacks
from keras.callbacks import ReduceLROnPlateau

optimizer_set = [keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=0.95),
                 keras.optimizers.Adam(lr=LEARNING_RATE),
                 keras.optimizers.RMSprop(lr=LEARNING_RATE)]

"""Code Here
建立實驗的比較組合
"""
reduce_lr_factor = [0.5, 0.9]
redice_lr_patient = [1, 5]

# %%
import itertools
results = {}
for i, (optim, reduce_factor, reduce_patient) in enumerate(itertools.product(optimizer_set, reduce_lr_factor, redice_lr_patient)):
    print("Numbers of exp: %i, reduce_factor: %.2f, reduce_patient: %i" % (i, reduce_factor, reduce_patient))
    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optim)
    
    """Code Here
    設定 reduce learning rate 的 callback function
    """
    reduce_lr = ReduceLROnPlateau(factor=reduce_factor, 
                                  min_lr=1e-12, 
                                  monitor='val_loss', 
                                  patience=reduce_patient, 
                                  verbose=1)
    
    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True,
              callbacks=[reduce_lr],
              verbose=False)

    # Collect results
    exp_name_tag = ("exp-%s" % (i))
    results[exp_name_tag] = {'train-loss': model.history.history["loss"],
                             'valid-loss': model.history.history["val_loss"],
                             'train-acc': model.history.history["accuracy"],
                             'valid-acc': model.history.history["val_accuracy"]}
# Out:
# ______________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 1.7526807205570095e-08.
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 1.5774126005396738e-08.
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.4196714204217643e-08.
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.2777042623923762e-08.
# Numbers of exp: 4, reduce_factor: 0.50, reduce_patient: 1
# Model: "functional_113"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_57 (InputLayer)        [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_168 (Bat (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_169 (Bat (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_170 (Bat (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Numbers of exp: 5, reduce_factor: 0.50, reduce_patient: 5
# Model: "functional_115"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_58 (InputLayer)        [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_171 (Bat (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_172 (Bat (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_173 (Bat (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.907348723406699e-09.
# Numbers of exp: 6, reduce_factor: 0.90, reduce_patient: 1
# Model: "functional_117"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_59 (InputLayer)        [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_174 (Bat (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_175 (Bat (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_176 (Bat (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
#
# Epoch 00002: ReduceLROnPlateau reducing learning rate to 1.716613851066029e-09.
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 1.5449524659594262e-09.
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 1.390457249339505e-09.
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 1.2514115743655907e-09.
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 1.1262703769610029e-09.
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 1.0136433692409242e-09.
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 9.122790523008462e-10.
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 8.210511270867472e-10.
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 7.389460043860652e-10.
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 6.650514139394659e-10.
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 5.985462625535121e-10.
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 5.386916412941645e-10.
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 4.848224821607517e-10.
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 4.3634021396066203e-10.
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 3.9270619256459586e-10.
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 3.534355808021417e-10.
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 3.180920277179311e-10.
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 2.862828224481362e-10.
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 2.57654547697328e-10.
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 2.3188908293558797e-10.
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 2.0870016964602555e-10.
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.878301514324221e-10.
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.690471387871817e-10.
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.5214242365946262e-10.
# Numbers of exp: 7, reduce_factor: 0.90, reduce_patient: 5
# Model: "functional_119"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_60 (InputLayer)        [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_177 (Bat (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_178 (Bat (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_179 (Bat (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 1.3692818129351637e-10.
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 1.2323535941716202e-10.
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.1091182972045034e-10.
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 9.982064549940439e-11.
# Numbers of exp: 8, reduce_factor: 0.50, reduce_patient: 1
# Model: "functional_121"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_61 (InputLayer)        [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_180 (Bat (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_181 (Bat (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_182 (Bat (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
#
# Epoch 00002: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Numbers of exp: 9, reduce_factor: 0.50, reduce_patient: 5
# Model: "functional_123"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_62 (InputLayer)        [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_183 (Bat (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_184 (Bat (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_185 (Bat (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# Numbers of exp: 10, reduce_factor: 0.90, reduce_patient: 1
# Model: "functional_125"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_63 (InputLayer)        [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_186 (Bat (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_187 (Bat (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_188 (Bat (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
#
# Epoch 00002: ReduceLROnPlateau reducing learning rate to 6.866455404264116e-09.
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 6.179809863837705e-09.
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 5.56182899735802e-09.
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 5.005646297462363e-09.
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 4.5050815078440115e-09.
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 4.054573476963697e-09.
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 3.6491162092033847e-09.
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 3.2842045083469887e-09.
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 2.955784017544261e-09.
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 2.6602056557578637e-09.
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 2.3941850502140483e-09.
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 2.154766565176658e-09.
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.9392899286430066e-09.
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.7453608558426481e-09.
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.5708247702583834e-09.
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.4137423232085667e-09.
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.2723681108717244e-09.
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.1451312897925449e-09.
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.030618190789312e-09.
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 9.275563317423519e-10.
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 8.348006785841022e-10.
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 7.513206057296884e-10.
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 6.761885551487268e-10.
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 6.085696946378505e-10.
# Numbers of exp: 11, reduce_factor: 0.90, reduce_patient: 5
# Model: "functional_127"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_64 (InputLayer)        [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_189 (Bat (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_190 (Bat (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_191 (Bat (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 5.477127251740655e-10.
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 4.929414376686481e-10.
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 4.4364731888180134e-10.
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 3.9928258199761756e-10.

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
# %matplotlib inline
NUM_COLORS = len(results.keys())

cm = plt.get_cmap('gist_rainbow')
cNorm  = colors.Normalize(vmin=0, vmax=NUM_COLORS-1)
scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
color_bar = [scalarMap.to_rgba(i) for i in range(NUM_COLORS)]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
